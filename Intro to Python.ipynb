# %% [markdown]
# # Introduction to Programming With Python

# %% [markdown]
# ## Intro to Python
# #### Python is a high level programming language meaning you don't have to write crazy syntax to carry out a task. The computer only understand machine language which is written in 0 and 1, and the closet language to the machine language is a low-levwl language and in python case that is C.
# #### Python is interpreted to C, and from C to machine language. Python has a lot of amazing benefits:
# - Python is very simple to understand
# - It has a very large community
# - It can do a lot of things from Back-end, AI/ML, Data Analysis e.t.c

# %% [markdown]
# ## Python Variables and Values
# #### Values are not the data to be stored for example: Divine, 12, True, 4.9. All these are values because the are actually data because the are usuable but to make more sense of it to become useful i.e Information we store them in a variable
# #### Variables are like containers for storing values e.g name, age, cgpa, all these are variables because thw now make sense to whoever is seeing them
#
# #### Some Rules for Naming Variables
# - Varibles can not have space in-between e.g (full name), instead you use camel case(fullName), pascal case(FullName), or snake case (full_name)
# - A minus sign cannot be used to join words (full-name)
# - Variable names cannot start with a number e.g (1st_name)
# - For readability and deocumentation sake, always use clear variables name
#
# #### Some examples of Variables
# - startup_name = "DM_Tech"
# - age = 23
# - cgpa = 4.9
# - isNigerian = True

# %%
# Hands on for Values and Variables
"DM_Tech" 
29
6.7
True
#all those mentioned above are values in python, but the don't make actual sense until the are being stored in a container called a variable for easy usability 

name_of_course = "Intro to Python"
height = 6.9
avg_price = 46.9
isReady = False
